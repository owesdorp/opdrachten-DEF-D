# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: XX     |  |
# | :-------------|:-------------|
# | Oscar Wesdorp| 6578365|
# |Carice von Morgen| 6452892|
# | Abel van OOrd (heeft alleen in de ochtend meegedaan, want was ziek)| 6580920 |
# | Planning Groep: 49   |Tijdstip / Tijdspanne  |
# |---|---|
# | Sanity checks | 12:00|
# | Pauze 1| 12:30-13:45 |
# | Sensor gemaakt|16:00|
# | Pauze 2| 15:30-15:45|
# | Vsc af| 17:30|

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="tekening 1.jpeg" alt="schets student 1" width="400"/>

# %%
# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!


import numpy as np

def capaciteit_plaatcondensator(A, d, eps_r):
    """
    Bereken de capaciteit van een vlakke-plaatcondensator.

    Parameters:
    A      : plaatoppervlak (m^2) — mag een getal of array zijn
    d      : afstand tussen de platen (m) — mag een getal of array zijn
    eps_r  : relatieve permittiviteit van het diëlektricum — mag een getal of array zijn

    Returns:
    C      : capaciteit in farad (F), zelfde vorm als de inputs
    """

    eps_0 = 8.854187817e-12   # permittiviteit van vacuüm (F/m)

    return eps_0 * eps_r * A / d

# Eén condensator
C = capaciteit_plaatcondensator(A=0.01, d=1e-4, eps_r=2.5)
print(C)

# Meerdere tegelijk (arrays)
A_array = np.array([0.01, 0.02, 0.03])
d_array = np.array([1e-4, 2e-4, 3e-4])
eps_array = np.array([2.5, 3.0, 4.0])

C_array = capaciteit_plaatcondensator(A_array, d_array, eps_array)
print(C_array)



# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.
# Out:
# 2.21354695425e-09
# [2.21354695e-09 2.65625635e-09 3.54167513e-09]

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

C = capaciteit_plaatcondensator(A=0.01, d=1e-4, eps_r=2.5)
print(C)

# Meerdere tegelijk (arrays)
A_array = np.array([0.01, 0.005])
d_array = np.array([2e-3, 0.018])
eps_array = np.array([3,40.5])

C_array = capaciteit_plaatcondensator(A_array, d_array, eps_array) *10**12
print(C_array)

print(f"Berekende capaciteit plaatcondensator groep 49 is {C_array[1]:.1f} pF")
# Out:
# 2.21354695425e-09
# [132.81281725  99.60961294]
# Berekende capaciteit plaatcondensator groep 49 is 99.6 pF

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](Osciloscoop.jpeg)
# ![scope meting 2](opstellingcondensator1.jpeg)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 49| 132,8 |0,67 | 0,60 |119,3|

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](schetsensensoren.jpeg)

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Pas deze tekst aan: Wij gaan een sensor maken die vochtigheid meet.

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](uitgewerkteschetsopstelling.jpeg)

# %%
# Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
import matplotlib.pyplot as plt

# Gegeven waarden
A = 0.005          # m^2
d = 0.018          # m
eps0 = 8.854187817e-12  # F/m

# Permittiviteit van 1 tot 80
eps_r = np.linspace(1, 80, 500)

# Capaciteit berekenen
C = eps0 * eps_r * A / d

# Plotten
plt.figure(figsize=(8,5))
plt.plot(C, eps_r, linewidth=2)
plt.ylabel("Relatieve permittiviteit $ε_r$")
plt.xlabel("Capaciteit C (F)")
plt.title("Capaciteit van een plaatcondensator als functie van ε_r")
plt.grid(True)
plt.show()

percentagewater= (eps_r/80)*100

plt.figure(figsize=(8,5))
plt.plot(C, percentagewater, linewidth=2)
plt.ylabel("percentage water (%)")
plt.xlabel("Capaciteit C (F)")
plt.title("Capaciteit van een plaatcondensator als functie van ε_r")
plt.grid(True)
plt.show()

# %% [markdown]
# Hierbij hebben we een permittiviteit een minimale permittiviteit aangenomen van 1.0, waarbij de spons helemaal droog is en kan worden gezien als lucht. De maximale permittiviteit is 80.0, wat de permitiviteit van water is. Hierbij is de spons dus 100% nat. Aangezien het water zich uniform verdeeld, is er een linear verband aangenomen tussenb de permitiviteit en het massapercentage water. Met dit in je achterhoofd en met behulp van de formule voor de capaciteit ontstaat er ook een linear verband tussen de Capacitiet en het percentage water in de spons.

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 2.5 |0.01 |
# | gemiddelde capaciteit| 99.6 |0,50 |
# | maximale capaciteit| 196.8 |0.98|

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](fotoopstelling1.jpg)
# ![meting 2](fotoopstelling2.jpg)

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.

eps0 = 8.854187817e-12   # permittiviteit van vacuüm (F/m)

def epsilon_r_uit_C(C, A, d):
    """
    C : gemeten capaciteit (float of array)
    A : plaatoppervlak (m^2)
    d : afstand tussen platen (m)
    """
    return C * d / (eps0 * A)




C_meet = np.array([11.0,36.5, 44.1,66.5,79.4, 146.2,190.3])*10**-12 
sigma_C = np.array([0.1,0.2,0.2,0.5,0.5,1.0,2.0]) * 1e-12   # onzekerheden in F ook gebruikt voor de permittiviteit aangezien het een linear verband. De onzekerheden zijn ingeschat op basis van de fluctuaties in de arduino waardes.
A = 0.005     # m^2
d = 0.018     # m

eps_r = epsilon_r_uit_C(C_meet, A, d)
print(eps_r)


plt.figure(figsize=(8,5))
plt.plot(C_meet ,eps_r, 'o-', label="ε(r) uit metingen")
plt.errorbar(C_meet, eps_r, yerr=sigma_C, xerr=sigma_C,
             fmt='o', capsize=4, label="ε(r) uit metingen")
plt.xlabel("Capaciteit (F)")
plt.ylabel("Relatieve permittiviteit ε(r)")
plt.title("Berekende ε(r) uit Arduino-metingen")
plt.grid(True)
plt.legend()
plt.show()

percentagewater= (eps_r/80)*100

plt.figure(figsize=(8,5))
plt.plot(C_meet ,percentagewater, 'o-', label="ε(r) uit metingen")
plt.errorbar(C_meet, percentagewater, yerr=sigma_C, xerr=sigma_C,
             fmt='o', capsize=4, label="ε(r) uit metingen")
plt.xlabel("Capaciteit (F)")
plt.ylabel("percentage water (%)")
plt.title("Berekende ε(r) uit Arduino-metingen")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [ 4.4724599  14.84043514 17.93049835 27.03805306 32.28302877 59.44305801
#  77.37355635]

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * verbetering 1: de opstelling stond af en toe schuin wat de gemeten capaciteit zeker beïnvloedde. We hebben dit met de hand goed gehouden maar een stabielere opstelling had zeker geholpen.
# * verbetering 2: Geen plastic tussen de metalen platen en de spons of een stof gebruiken die een nog lagere permittiviteit heeft. Dit kan helaas niet aangezien we niet echt andere opties hadden qua materiaal keuze.

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](verbeterdeopstelling.jpeg)

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij
# Gegeven waarden
A = 0.005          # m^2
d = 0.018          # m
eps0 = 8.854187817e-12  # F/m

# Permittiviteit van 1 tot 80
eps_r = np.linspace(1, 80, 500)

# Capaciteit berekenen
C = eps0 * eps_r * A / d

percentagewater= (eps_r/80)*100

plt.figure(figsize=(8,5))
plt.plot(C, percentagewater, linewidth=2)
plt.ylabel("percentage water (%)")
plt.xlabel("Capaciteit C (F)")
plt.title("ontwerpgrafiek")
plt.grid(True)
plt.show()

#uiteindelijke grafiek

# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.

eps0 = 8.854187817e-12   # permittiviteit van vacuüm (F/m)

def epsilon_r_uit_C(C, A, d):
    """
    C : gemeten capaciteit (float of array)
    A : plaatoppervlak (m^2)
    d : afstand tussen platen (m)
    """
    return C * d / (eps0 * A)




C_meet = np.array([11.0,36.5, 44.1,66.5,79.4, 146.2,190.3])*10**-12 
sigma_C = np.array([0.1,0.2,0.2,0.5,0.5,1.0,2.0]) * 1e-12   # onzekerheden in F ook gebruikt voor de permittiviteit aangezien het een linear verband. De onzekerheden zijn ingeschat op basis van de fluctuaties in de arduino waardes.
A = 0.005     # m^2
d = 0.018     # m

eps_r = epsilon_r_uit_C(C_meet, A, d)
print(eps_r)


plt.figure(figsize=(8,5))
plt.plot(C_meet ,eps_r, 'o-', label="ε(r) uit metingen")
plt.errorbar(C_meet, eps_r, yerr=sigma_C, xerr=sigma_C,
             fmt='o', capsize=4, label="ε(r) uit metingen")
plt.xlabel("Capaciteit (F)")
plt.ylabel("Relatieve permittiviteit ε(r)")
plt.title("Berekende ε(r) uit Arduino-metingen")
plt.grid(True)
plt.legend()
plt.show()

percentagewater= (eps_r/80)*100

plt.figure(figsize=(8,5))
plt.plot(C_meet ,percentagewater, 'o-', label="ε(r) uit metingen")
plt.errorbar(C_meet, percentagewater, yerr=sigma_C, xerr=sigma_C,
             fmt='o', capsize=4, label="ε(r) uit metingen")
plt.xlabel("Capaciteit (F)")
plt.ylabel("percentage water (%)")
plt.title("Berekende ε(r) uit Arduino-metingen")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [ 4.4724599  14.84043514 17.93049835 27.03805306 32.28302877 59.44305801
#  77.37355635]

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.
# Onze sensor is zeker geschikt, er kan hiermee bepaald worden hoe vochtig iets is (percentage water). Onze grafiek klopte al goed genoeg, waardoor we niet vonden dat een iteratie nodig was. Ook zat er geen verschil tussen de ontwerpgrafiek en onze kalibratiegrafiek, waarbij de onzekerheid er wel was maar klein.  Er was een kleine schommeling in de arduino waardes, die steeds iets groter werden naarmate de capaciteit groeide. Dit kwam omdat het water niet perfect uniform verdeeld was in de spons, wat zorgde dat de onzekerheid groter werdt naarmate er meer water in de spons kwam. Tot slot kwam er uit de metingen en grafieken dat de vlakke plaat formule inderdaad gebruikt kon worden om het waterpecentage te meten, omdat er uit kwam dat het verband tussen $\epsilon_r$ en de capaciteit een liniear verband was.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.
#
# Hierbij hebben we een permittiviteit een minimale permittiviteit aangenomen van 1.0, waarbij de spons helemaal droog is en kan worden gezien als lucht. De maximale permittiviteit is 80.0, wat de permitiviteit van water is. Hierbij is de spons dus 100% nat. Aangezien het water zich uniform verdeeld, is er een linear verband aangenomen tussenb de permitiviteit en het massapercentage water. Met dit in je achterhoofd en met behulp van de formule voor de capaciteit ontstaat er ook een linear verband tussen de Capacitiet en het percentage water in de spons.

# %%
A = 0.005          # m^2
d = 0.018          # m
eps0 = 8.854187817e-12  # F/m

# Permittiviteit van 1 tot 80
eps_r = np.linspace(1, 80, 500)

# Capaciteit berekenen
C = eps0 * eps_r * A / d

percentagewater= (eps_r/80)*100

plt.figure(figsize=(8,5))
plt.plot(C, percentagewater, linewidth=2)
plt.ylabel("percentage water (%)")
plt.xlabel("Capaciteit C (F)")
plt.title("ontwerpgrafiek")
plt.grid(True)
plt.show()

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.
# # Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# # als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# # constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# # Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!

# %%
import numpy as np

def capaciteit_plaatcondensator(A, d, eps_r):
    """
    Bereken de capaciteit van een vlakke-plaatcondensator.

    Parameters:
    A      : plaatoppervlak (m^2) — mag een getal of array zijn
    d      : afstand tussen de platen (m) — mag een getal of array zijn
    eps_r  : relatieve permittiviteit van het diëlektricum — mag een getal of array zijn

    Returns:
    C      : capaciteit in farad (F), zelfde vorm als de inputs
    """

    eps_0 = 8.854187817e-12   # permittiviteit van vacuüm (F/m)

    return eps_0 * eps_r * A / d

# Eén condensator
C = capaciteit_plaatcondensator(A=0.01, d=1e-4, eps_r=2.5)
print(C)

# Meerdere tegelijk (arrays)
A_array = np.array([0.01, 0.02, 0.03])
d_array = np.array([1e-4, 2e-4, 3e-4])
eps_array = np.array([2.5, 3.0, 4.0])

C_array = capaciteit_plaatcondensator(A_array, d_array, eps_array)
print(C_array)

# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

C = capaciteit_plaatcondensator(A=0.01, d=1e-4, eps_r=2.5)
print(C)

# Meerdere tegelijk (arrays)
A_array = np.array([0.01, 0.005])
d_array = np.array([2e-3, 0.018])
eps_array = np.array([3,40.5])

C_array = capaciteit_plaatcondensator(A_array, d_array, eps_array) *10**12
print(C_array)

print(f"Berekende capaciteit plaatcondensator groep 49 is {C_array[1]:.1f} pF")

![scope meting 2](![opstelling condensator 1.jpeg](<attachment:opstelling condensator 1.jpeg>))
# Out:
# 2.21354695425e-09
# [2.21354695e-09 2.65625635e-09 3.54167513e-09]
# 2.21354695425e-09
# [132.81281725  99.60961294]
# Berekende capaciteit plaatcondensator groep 49 is 99.6 pF
# Het systeem kan het opgegeven bestand niet vinden.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.
#
# Onze sensor is zeker geschikt, er kan hiermee bepaald worden hoe vochtig iets is (percentage water). Onze grafiek klopte al goed genoeg, waardoor we niet vonden dat een iteratie nodig was. Ook zat er geen verschil tussen de ontwerpgrafiek en onze kalibratiegrafiek, waarbij de onzekerheid er wel was maar klein.  Er was een kleine schommeling in de arduino waardes, die steeds iets groter werden naarmate de capaciteit groeide. Dit kwam omdat het water niet perfect uniform verdeeld was in de spons, wat zorgde dat de onzekerheid groter werdt naarmate er meer water in de spons kwam. Tot slot kwam er uit de metingen en grafieken dat de vlakke plaat formule inderdaad gebruikt kon worden om het waterpecentage te meten, omdat er uit kwam dat het verband tussen $\epsilon_r$ en de capaciteit een liniear verband was.

# %%
A = 0.005          # m^2
d = 0.018          # m
eps0 = 8.854187817e-12  # F/m

# Permittiviteit van 1 tot 80
eps_r = np.linspace(1, 80, 500)

# Capaciteit berekenen
C = eps0 * eps_r * A / d

percentagewater= (eps_r/80)*100

plt.figure(figsize=(8,5))
plt.plot(C, percentagewater, linewidth=2)
plt.ylabel("percentage water (%)")
plt.xlabel("Capaciteit C (F)")
plt.title("ontwerpgrafiek")
plt.grid(True)
plt.show()

#uiteindelijke grafiek

# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.

eps0 = 8.854187817e-12   # permittiviteit van vacuüm (F/m)

def epsilon_r_uit_C(C, A, d):
    """
    C : gemeten capaciteit (float of array)
    A : plaatoppervlak (m^2)
    d : afstand tussen platen (m)
    """
    return C * d / (eps0 * A)




C_meet = np.array([11.0,36.5, 44.1,66.5,79.4, 146.2,190.3])*10**-12 
sigma_C = np.array([0.1,0.2,0.2,0.5,0.5,1.0,2.0]) * 1e-12   # onzekerheden in F ook gebruikt voor de permittiviteit aangezien het een linear verband. De onzekerheden zijn ingeschat op basis van de fluctuaties in de arduino waardes.
A = 0.005     # m^2
d = 0.018     # m

eps_r = epsilon_r_uit_C(C_meet, A, d)
print(eps_r)


plt.figure(figsize=(8,5))
plt.plot(C_meet ,eps_r, 'o-', label="ε(r) uit metingen")
plt.errorbar(C_meet, eps_r, yerr=sigma_C, xerr=sigma_C,
             fmt='o', capsize=4, label="ε(r) uit metingen")
plt.xlabel("Capaciteit (F)")
plt.ylabel("Relatieve permittiviteit ε(r)")
plt.title("Berekende ε(r) uit Arduino-metingen")
plt.grid(True)
plt.legend()
plt.show()

percentagewater= (eps_r/80)*100

plt.figure(figsize=(8,5))
plt.plot(C_meet ,percentagewater, 'o-', label="ε(r) uit metingen")
plt.errorbar(C_meet, percentagewater, yerr=sigma_C, xerr=sigma_C,
             fmt='o', capsize=4, label="ε(r) uit metingen")
plt.xlabel("Capaciteit (F)")
plt.ylabel("percentage water (%)")
plt.title("Berekende ε(r) uit Arduino-metingen")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [ 4.4724599  14.84043514 17.93049835 27.03805306 32.28302877 59.44305801
#  77.37355635]
